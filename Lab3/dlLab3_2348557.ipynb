# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikbanerjee/DL_Lab/blob/main/dlLab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab 3**
# 1.Imagine you are the manager of an online retail store, and you want to optimize the pricing strategy for a specific product based on real-time data with the objective to minimize the revenue lost on the marketing/advertisements of a product. Assume the revenue function is given by
#
# **ƒ (w) = 0.5w2-30w +100**, where x is the cost on the product advertisement. Start with an initial price as w=20 and find the optimal price (w) using appropriate momentum based optimization algorithm that could minimize the revenue lost. (Note: repeat for at least 3 iterations with learning rate=0.1 & momentum=0.9)
#
#
# 2.You are working as a data scientist for a healthcare company that aims to predict the likelihood of patients developing a certain disease based on various medical parameters. You have been tasked with developing a deep learning model using a dataset obtained from Kaggle or any other repository. This dataset contains information about patients' demographics, medical history, and test results.
#
# Your goal is to build a neural network model that can effectively predict the likelihood of a patient developing the disease. However, due to the complexity of the dataset and potential overfitting issues, you decide to implement three different regularization techniques: L1 regularization, L2 regularization, and elastic net regularization.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from keras import layers, Sequential, regularizers
from imblearn.over_sampling import RandomOverSampler
from keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix,precision_recall_curve,roc_auc_score,auc,roc_curve

# %% [markdown]
# 1.Imagine you are the manager of an online retail store, and you want to optimize the pricing strategy for a specific product based on real-time data with the objective to minimize the revenue lost on the marketing/advertisements of a product. Assume the revenue function is given by
#
# ƒ (w) = 0.5w2 -30w +100, where w is the cost on the product advertisement.
#
# Start with an initial price as w=20 and find the optimal price (w) using appropriate momentum based optimization algorithm that could minimize the revenue lost.

# %%
def function(x):
  return 0.5*x**2 -30*x + 100
def gradient_descent(x):
  momentum = 0
  w = 20
  for i in range(3):
    gradient = x - 30
    momentum = 0.9 * momentum + 0.1 *gradient
    w  = w -  momentum
  return w
print("Estimated Optimal Price",gradient_descent(20))
# Out:
# Estimated Optimal Price 25.61

# %%
data = pd.read_csv("/content/heart_2020_cleaned.csv")
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26382 entries, 0 to 26381
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      26382 non-null  object
#  1   BMI               26382 non-null  float64
#  2   Smoking           26382 non-null  object
#  3   AlcoholDrinking   26382 non-null  object
#  4   Stroke            26382 non-null  object
#  5   PhysicalHealth    26382 non-null  float64
#  6   MentalHealth      26382 non-null  float64
#  7   DiffWalking       26382 non-null  object
#  8   Sex               26382 non-null  object
#  9   AgeCategory       26382 non-null  object
#  10  Race              26382 non-null  object
#  11  Diabetic          26382 non-null  object
#  12  PhysicalActivity  26382 non-null  object
#  13  GenHealth         26382 non-null  object
#  14  SleepTime         26382 non-null  float64
#  15  Asthma            26382 non-null  object
#  16  KidneyDisease     26382 non-null  object
#  17  SkinCancer        26381 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 3.6+ MB

# %%
data.describe()
# Out:
#                 BMI  PhysicalHealth  MentalHealth     SleepTime
# count  26382.000000    26382.000000  26382.000000  26382.000000
# mean      28.182574        3.782238      3.947123      7.136874
# std        6.349593        8.358024      7.946838      1.499008
# min       12.400000        0.000000      0.000000      1.000000
# 25%       23.750000        0.000000      0.000000      6.000000
# 50%       27.250000        0.000000      0.000000      7.000000
# 75%       31.320000        2.000000      4.000000      8.000000
# max       83.000000       30.000000     30.000000     24.000000

# %%
data.describe(include='object')
# Out:
#        HeartDisease Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# count         26382   26382           26382  26382       26382   26382
# unique            2       2               2      2           2       2
# top              No      No              No     No          No  Female
# freq          23943   15296           24646  25298       22303   14078
#
#        AgeCategory   Race Diabetic PhysicalActivity  GenHealth Asthma  \
# count        26382  26382    26382            26382      26382  26382
# unique          13      6        4                2          5      2
# top          65-69  White       No              Yes  Very good     No
# freq          2937  18680    22082            20189       8954  22666
#
#        KidneyDisease SkinCancer
# count          26382      26381
# unique             3          2
# top               No         No
# freq           25315      23365

# %%
data.isna().sum().plot(kind='barh')
# Out:
# <Axes: >

# %%
gender_count = data['Sex'].value_counts()
gender_count
# Out:
# Female    14078
# Male      12304
# Name: Sex, dtype: int64

# %%
plt.title("Gender Distribution", fontsize = 12, weight='bold')
plt.pie(gender_count,labels=gender_count.index,radius=1, autopct='%.2f%%')
plt.show()

# %%
lb = LabelEncoder()
cat_cols = [col for col in data.columns if data[col].dtype == 'object']
for col in cat_cols:
    data[col] = lb.fit_transform(data[col])
data.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2          30.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1          4        5.0       1              1           1
# 1                 1          4        7.0       0              1           0
# 2                 1          1        8.0       1              1           0
# 3                 0          2        6.0       0              1           1
# 4                 1          4        8.0       0              1           0

# %%
sns.countplot(data = data, x = 'HeartDisease')
plt.title("Distribution of Patients with HeartDisease")
plt.show()

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
x = data.drop(columns=['HeartDisease'])
y = data['HeartDisease']

# %%
ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(x, y)
x_train,x_test,y_train,y_test = train_test_split(x_ros,y_ros,test_size=0.2)

# %%
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %% [markdown]
# **Simple Neural Network Model**
#
# ---

# %%
model1 = Sequential()
model1.add(Dense(units=200, input_dim=17, kernel_initializer='uniform', activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(units=200,  kernel_initializer='uniform', activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(units=1, kernel_initializer='uniform',activation='sigmoid'))
print(model1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               3600
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 44001 (171.88 KB)
# Trainable params: 44001 (171.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model1.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model1.fit(x= x_train, y=y_train,  validation_split=0.8, epochs= 100,  batch_size=500, verbose=2)
# Out:
# Epoch 1/100
# 16/16 -
# 16/16 - 1s - loss: 0.5301 - accuracy: 0.7421 - val_loss: 0.5352 - val_accuracy: 0.7586 - 577ms/epoch - 36ms/step
# Epoch 97/100
# 16/16 - 1s - loss: 0.5263 - accuracy: 0.7408 - val_loss: 0.5383 - val_accuracy: 0.7607 - 529ms/epoch - 33ms/step
# Epoch 98/100
# 16/16 - 1s - loss: 0.5276 - accuracy: 0.7396 - val_loss: 0.5332 - val_accuracy: 0.7520 - 508ms/epoch - 32ms/step
# Epoch 99/100
# 16/16 - 1s - loss: 0.5299 - accuracy: 0.7421 - val_loss: 0.5292 - val_accuracy: 0.7603 - 528ms/epoch - 33ms/step
# Epoch 100/100
# 16/16 - 1s - loss: 0.5277 - accuracy: 0.7376 - val_loss: 0.5325 - val_accuracy: 0.7478 - 524ms/epoch - 33ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model1.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 300/300 [==============================] - 2s 6ms/step - loss: 0.5312 - accuracy: 0.7520
#
#
# accuracy= 0.752035915851593

# %%
predictions1 = (model1.predict(x_test) > 0.5).astype("int32")
# Out:
# 300/300 [==============================] - 3s 9ms/step

# %%
print(classification_report(predictions1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76      5149
#            1       0.71      0.77      0.74      4429
#
#     accuracy                           0.75      9578
#    macro avg       0.75      0.75      0.75      9578
# weighted avg       0.75      0.75      0.75      9578

# %% [markdown]
# **Applying L1 Regularization**
#
# ---
# L1 regularization is also referred to as lasso regression. In this type of regularization, the absolute value of the magnitude of coefficients or weights multiplied with a regularizer term is added to the loss or cost function. It can be represented with the following equation.
#
# ![image.png](data:image/png;base64,...)
#
# A fraction of the sum of absolute values of weights to the loss function is added in the L1 regularization. In this way, you will be able to eliminate some coefficients with lesser values by pushing those values towards 0. You can observe the following by using L1 regularization:
#
# - Since the L1 regularization adds an absolute value as a penalty to the cost function, the feature selection will be done by retaining only some important features and eliminating the lower or unimportant features.
# - This technique is also robust to outliers, i.e., the model will be able to easily learn about outliers in the dataset.
# - This technique will not be able to learn complex patterns from the input data.

# %%
model = Sequential()
model.add(Dense(units=200, input_dim=17, kernel_initializer='uniform', activation='relu',kernel_regularizer=regularizers.l1(0.01)))
model.add(Dropout(0.5))
model.add(Dense(units=200,  kernel_initializer='uniform', activation='relu',kernel_regularizer=regularizers.l1(0.01)))
model.add(Dropout(0.5))
model.add(Dense(units=1, kernel_initializer='uniform',activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 200)               3600
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense_4 (Dense)             (None, 200)               40200
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_5 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 44001 (171.88 KB)
# Trainable params: 44001 (171.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model.fit(x= x_train, y=y_train,  validation_split=0.8, epochs=100,  batch_size=500, verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 3s - loss: 4.0858 - accuracy: 0.5422 - val_loss: 2.2952 - val_accuracy: 0.6737 - 3s/epoch - 166ms/step
# Epoch 2/100
# 16/16 - 1s - loss: 1.7453 - accuracy: 0.5993 - val_loss: 1.3802 - val_accuracy: 0.6944 - 533ms/epoch - 33ms/step
# Epoch 3/100
# 16/16 - 1s - loss: 1.3445 - accuracy: 0.6426 - val_loss: 1.2492 - val_accuracy: 0.6594 - 534ms/epoch - 33ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 1.1562 - accuracy: 0.6773 - val_loss: 1.1060 - val_accuracy: 0.7142 - 280ms/epoch - 17ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 1.1487 - accuracy: 0.6870 - val_loss: 1.1214 - val_accuracy: 0.7084 - 290ms/epoch - 18ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 1.1418 - accuracy: 0.6905 - val_loss: 1.1155 - val_accuracy: 0.7082 - 279ms/epoch - 17ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 1.1486 - accuracy: 0.6913 - val_loss: 1.1328 - val_accuracy: 0.6930 - 275ms/epoch - 17ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 1.1519 - accuracy: 0.6839 - val_loss: 1.1548 - val_accuracy: 0.6862 - 270ms/epoch - 17ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 300/300 [==============================] - 0s 2ms/step - loss: 1.1537 - accuracy: 0.6848
#
#
# accuracy= 0.6847984790802002

# %%
predictions = (model.predict(x_test) > 0.5).astype("int32")
# Out:
# 300/300 [==============================] - 1s 2ms/step

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.86      0.58      2459
#            1       0.93      0.62      0.75      7119
#
#     accuracy                           0.68      9578
#    macro avg       0.68      0.74      0.66      9578
# weighted avg       0.80      0.68      0.70      9578

# %% [markdown]
# **Applying L2 Regularization**
#
# ---
#
# According to regression analysis, L2 regularization is also called ridge regression. In this type of regularization, the squared magnitude of the coefficients or weights multiplied with a regularizer term is added to the loss or cost function. L2 regression can be represented with the following mathematical equation.
#
# Loss:
#
# ![image.png](data:image/png;base64,...)
#
# You can see that a fraction of the sum of squared values of weights is added to the loss function. Thus, when gradient descent is applied on loss, the weight update seems to be consistent by giving almost equal emphasis on all features. You can observe the following:
#
# - Lambda is the hyperparameter that is tuned to prevent overfitting i.e. penalize the insignificant weights by forcing them to be small but not zero.
# - L2 regularization works best when all the weights are roughly of the same size, i.e., input features are of the same range.
# - This technique also helps the model to learn more complex patterns from data without overfitting easily.

# %%
model2 = Sequential()
model2.add(Dense(units=200, input_dim=17, kernel_initializer='uniform', activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model2.add(Dropout(0.5))
model2.add(Dense(units=200,  kernel_initializer='uniform', activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model2.add(Dropout(0.5))
model2.add(Dense(units=1, kernel_initializer='uniform',activation='sigmoid'))

print(model2.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 200)               3600
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_7 (Dense)             (None, 200)               40200
#
#  dropout_5 (Dropout)         (None, 200)               0
#
#  dense_8 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 44001 (171.88 KB)
# Trainable params: 44001 (171.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model2.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model2.fit(x= x_train, y=y_train,  validation_split=0.8, epochs=200,  batch_size=500, verbose=2)
# Out:
# Epoch 1/200
# 16/16 - 2s - loss: 0.7927 - accuracy: 0.6155 - val_loss: 0.6690 - val_accuracy: 0.6942 - 2s/epoch - 95ms/step
# Epoch 2/200
# 16/16 - 0s - loss: 0.6491 - accuracy: 0.6995 - val_loss: 0.6070 - val_accuracy: 0.7116 - 429ms/epoch - 27ms/step
# Epoch 3/200
# Epoch 22/200
# 16/16 - 0s - loss: 0.5963 - accuracy: 0.7010 - val_loss: 0.5657 - val_accuracy: 0.7263 - 276ms/epoch - 17ms/step
# Epoch 23/200
# 16/16 - 0s - loss: 0.5907 - accuracy: 0.7093 - val_loss: 0.5625 - val_accuracy: 0.7313 - 276ms/epoch - 17ms/step
# Epoch 24/200
# 16/16 - 0s - loss: 0.5882 - accuracy: 0.7149 - val_loss: 0.5590 - val_accuracy: 0.7334 - 433ms/epoch - 27ms/step
# Epoch 25/200
# 16/16 - 0s - loss: 0.5835 - accuracy: 0.7165 - val_loss: 0.5607 - val_accuracy: 0.7340 - 269ms/epoch - 17ms/step
# Epoch 26/200
# 16/16 - 0s - loss: 0.5936 - accuracy: 0.7115 - val_loss: 0.5656 - val_accuracy: 0.7312 - 292ms/epoch - 18ms/step
# Epoch 27/200
# 16/16 - 0s - loss: 0.5878 - accuracy: 0.7111 - val_loss: 0.5611 - val_accuracy: 0.7307 - 447ms/epoch - 28ms/step
# Epoch 28/200
# 16/16 - 0s - loss: 0.5907 - accuracy: 0.7127 - val_loss: 0.5757 - val_accuracy: 0.7180 - 278ms/epoch - 17ms/step
# Epoch 29/200
# 16/16 - 0s - loss: 0.5963 - accuracy: 0.7106 - val_loss: 0.5697 - val_accuracy: 0.7293 - 485ms/epoch - 30ms/step
# Epoch 30/200
# 16/16 - 1s - loss: 0.5947 - accuracy: 0.7051 - val_loss: 0.5673 - val_accuracy: 0.7312 - 538ms/epoch - 34ms/step
# Epoch 31/200
# 16/16 - 1s - loss: 0.5880 - accuracy: 0.7122 - val_loss: 0.5686 - val_accuracy: 0.7315 - 531ms/epoch - 33ms/step
# Epoch 32/200
# 16/16 - 1s - loss: 0.5913 - accuracy: 0.7120 - val_loss: 0.5593 - val_accuracy: 0.7307 - 526ms/epoch - 33ms/step
# Epoch 33/200
# 16/16 - 1s - loss: 0.5868 - accuracy: 0.7194 - val_loss: 0.5783 - val_accuracy: 0.7140 - 513ms/epoch - 32ms/step
# Epoch 34/200
# 16/16 - 0s - loss: 0.5837 - accuracy: 0.7156 - val_loss: 0.5550 - val_accuracy: 0.7361 - 272ms/epoch - 17ms/step
# Epoch 35/200
# 16/16 - 0s - loss: 0.5879 - accuracy: 0.7139 - val_loss: 0.5725 - val_accuracy: 0.7365 - 268ms/epoch - 17ms/step
# Epoch 36/200
# 16/16 - 0s - loss: 0.5956 - accuracy: 0.7021 - val_loss: 0.5647 - val_accuracy: 0.7281 - 267ms/epoch - 17ms/step
# Epoch 37/200
# 16/16 - 0s - loss: 0.5927 - accuracy: 0.6995 - val_loss: 0.5611 - val_accuracy: 0.7311 - 264ms/epoch - 17ms/step
# Epoch 38/200
# 16/16 - 0s - loss: 0.5905 - accuracy: 0.7104 - val_loss: 0.5605 - val_accuracy: 0.7377 - 279ms/epoch - 17ms/step
# Epoch 39/200
# 16/16 - 0s - loss: 0.5914 - accuracy: 0.7120 - val_loss: 0.5780 - val_accuracy: 0.7081 - 255ms/epoch - 16ms/step
# Epoch 150/200
# 16/16 - 0s - loss: 0.5893 - accuracy: 0.7128 - val_loss: 0.5558 - val_accuracy: 0.7402 - 274ms/epoch - 17ms/step
# Epoch 151/200
# 16/16 - 0s - loss: 0.5867 - accuracy: 0.7096 - val_loss: 0.5537 - val_accuracy: 0.7261 - 448ms/epoch - 28ms/step
# Epoch 152/200
# 16/16 - 1s - loss: 0.5881 - accuracy: 0.7148 - val_loss: 0.5548 - val_accuracy: 0.7390 - 886ms/epoch - 55ms/step
# Epoch 153/200
# 16/16 - 0s - loss: 0.5858 - accuracy: 0.7143 - val_loss: 0.5538 - val_accuracy: 0.7426 - 313ms/epoch - 20ms/step
# Epoch 154/200
# 16/16 - 0s - loss: 0.5871 - accuracy: 0.7250 - val_loss: 0.5592 - val_accuracy: 0.7261 - 262ms/epoch - 16ms/step
# Epoch 155/200
# 16/16 - 0s - loss: 0.5876 - accuracy: 0.7119 - val_loss: 0.5617 - val_accuracy: 0.7260 - 255ms/epoch - 16ms/step
# Epoch 156/200
# 16/16 - 0s - loss: 0.5863 - accuracy: 0.7171 - val_loss: 0.5682 - val_accuracy: 0.7178 - 287ms/epoch - 18ms/step
# Epoch 157/200
# 16/16 - 0s - loss: 0.6006 - accuracy: 0.7084 - val_loss: 0.5544 - val_accuracy: 0.7415 - 273ms/epoch - 17ms/step
# Epoch 158/200
# 16/16 - 0s - loss: 0.6049 - accuracy: 0.7038 - val_loss: 0.5589 - val_accuracy: 0.7415 - 276ms/epoch - 17ms/step
# Epoch 159/200
# 16/16 - 0s - loss: 0.5983 - accuracy: 0.7124 - val_loss: 0.5676 - val_accuracy: 0.7284 - 270ms/epoch - 17ms/step
# Epoch 160/200
# 16/16 - 0s - loss: 0.5931 - accuracy: 0.7174 - val_loss: 0.5609 - val_accuracy: 0.7300 - 272ms/epoch - 17ms/step
# Epoch 161/200
# 16/16 - 0s - loss: 0.5961 - accuracy: 0.7145 - val_loss: 0.5810 - val_accuracy: 0.7151 - 260ms/epoch - 16ms/step
# Epoch 162/200
# 16/16 - 0s - loss: 0.5912 - accuracy: 0.7136 - val_loss: 0.5567 - val_accuracy: 0.7271 - 279ms/epoch - 17ms/step
# Epoch 163/200
# 16/16 - 0s - loss: 0.5849 - accuracy: 0.7173 - val_loss: 0.5549 - val_accuracy: 0.7346 - 429ms/epoch - 27ms/step
# Epoch 164/200
# 16/16 - 0s - loss: 0.5913 - accuracy: 0.7107 - val_loss: 0.5579 - val_accuracy: 0.7282 - 262ms/epoch - 16ms/step
# Epoch 165/200
# 16/16 - 0s - loss: 0.5817 - accuracy: 0.7182 - val_loss: 0.5564 - val_accuracy: 0.7268 - 279ms/epoch - 17ms/step
# Epoch 166/200
# 16/16 - 0s - loss: 0.5779 - accuracy: 0.7216 - val_loss: 0.5671 - val_accuracy: 0.7213 - 443ms/epoch - 28ms/step
# Epoch 167/200
# 16/16 - 0s - loss: 0.5839 - accuracy: 0.7207 - val_loss: 0.5456 - val_accuracy: 0.7442 - 278ms/epoch - 17ms/step
# Epoch 168/200
# Epoch 187/200
# 16/16 - 0s - loss: 0.5984 - accuracy: 0.7094 - val_loss: 0.5778 - val_accuracy: 0.7123 - 284ms/epoch - 18ms/step
# Epoch 188/200
# 16/16 - 0s - loss: 0.5885 - accuracy: 0.7094 - val_loss: 0.5481 - val_accuracy: 0.7440 - 264ms/epoch - 16ms/step
# Epoch 189/200
# 16/16 - 0s - loss: 0.5834 - accuracy: 0.7213 - val_loss: 0.5887 - val_accuracy: 0.6920 - 252ms/epoch - 16ms/step
# Epoch 190/200
# 16/16 - 0s - loss: 0.5945 - accuracy: 0.7075 - val_loss: 0.5585 - val_accuracy: 0.7359 - 275ms/epoch - 17ms/step
# Epoch 191/200
# 16/16 - 0s - loss: 0.5873 - accuracy: 0.7124 - val_loss: 0.5549 - val_accuracy: 0.7359 - 287ms/epoch - 18ms/step
# Epoch 192/200
# 16/16 - 0s - loss: 0.5849 - accuracy: 0.7109 - val_loss: 0.5552 - val_accuracy: 0.7271 - 260ms/epoch - 16ms/step
# Epoch 193/200
# 16/16 - 0s - loss: 0.5859 - accuracy: 0.7186 - val_loss: 0.5585 - val_accuracy: 0.7318 - 259ms/epoch - 16ms/step
# Epoch 194/200
# 16/16 - 0s - loss: 0.5849 - accuracy: 0.7141 - val_loss: 0.5590 - val_accuracy: 0.7209 - 266ms/epoch - 17ms/step
# Epoch 195/200
# 16/16 - 0s - loss: 0.5907 - accuracy: 0.7137 - val_loss: 0.5760 - val_accuracy: 0.7059 - 278ms/epoch - 17ms/step
# Epoch 196/200
# 16/16 - 0s - loss: 0.5894 - accuracy: 0.7109 - val_loss: 0.5524 - val_accuracy: 0.7416 - 277ms/epoch - 17ms/step
# Epoch 197/200
# 16/16 - 0s - loss: 0.5881 - accuracy: 0.7152 - val_loss: 0.5504 - val_accuracy: 0.7427 - 278ms/epoch - 17ms/step
# Epoch 198/200
# 16/16 - 0s - loss: 0.5922 - accuracy: 0.7063 - val_loss: 0.5553 - val_accuracy: 0.7352 - 446ms/epoch - 28ms/step
# Epoch 199/200
# 16/16 - 0s - loss: 0.5820 - accuracy: 0.7149 - val_loss: 0.5492 - val_accuracy: 0.7419 - 283ms/epoch - 18ms/step
# Epoch 200/200
# 16/16 - 0s - loss: 0.5856 - accuracy: 0.7201 - val_loss: 0.5559 - val_accuracy: 0.7343 - 281ms/epoch - 18ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model2.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 300/300 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7398
#
#
# accuracy= 0.7398204207420349

# %%
predictions2 = (model2.predict(x_test) > 0.5).astype("int32")
# Out:
# 300/300 [==============================] - 0s 1ms/step

# %%
print(classification_report(predictions2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.85      0.69      3268
#            1       0.90      0.68      0.78      6310
#
#     accuracy                           0.74      9578
#    macro avg       0.74      0.77      0.73      9578
# weighted avg       0.79      0.74      0.75      9578

# %% [markdown]
# **Applying Elastic Net Regularization**
#
# ---
#
# The third type of regularization, uses both L1 and L2 regularizations to produce most optimized output.
# In addition to setting and choosing a lambda value elastic net also allows us to tune the alpha parameter where 𝞪 = 0 corresponds to ridge and 𝞪 = 1 to lasso. Simply put, if you plug in 0 for alpha, the penalty function reduces to the L1 (ridge) term and if we set alpha to 1 we get the L2 (lasso) term.
#
# Loss:
# ![image.png](data:image/png;base64,...)
#
# Therefore we can choose an alpha value between 0 and 1 to optimize the elastic net(here we can adjust the weightage of each regularization,thus giving the name elastic). Effectively this will shrink some coefficients and set some to 0 for sparse selection.

# %%
model3 = Sequential()
model3.add(Dense(units=200, input_dim=17, kernel_initializer='uniform', activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model3.add(Dropout(0.5))
model3.add(Dense(units=200,  kernel_initializer='uniform', activation='relu',kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model3.add(Dropout(0.5))
model3.add(Dense(units=1, kernel_initializer='uniform',activation='sigmoid'))
print(model3.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 200)               3600
#
#  dropout_6 (Dropout)         (None, 200)               0
#
#  dense_10 (Dense)            (None, 200)               40200
#
#  dropout_7 (Dropout)         (None, 200)               0
#
#  dense_11 (Dense)            (None, 1)                 201
#
# =================================================================
# Total params: 44001 (171.88 KB)
# Trainable params: 44001 (171.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model3.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model3.fit(x= x_train, y=y_train,  validation_split=0.8, epochs=100,  batch_size=500, verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 2s - loss: 4.1419 - accuracy: 0.5318 - val_loss: 2.3354 - val_accuracy: 0.6184 - 2s/epoch - 133ms/step
# Epoch 2/100
# 16/16 - 1s - loss: 1.7540 - accuracy: 0.5993 - val_loss: 1.3610 - val_accuracy: 0.6301 - 558ms/epoch - 35ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 1.3484 - accuracy: 0.6284 - val_loss: 1.2666 - val_accuracy: 0.6562 - 452ms/epoch - 28ms/step
# Epoch 4/100
# 16/16 - 1s - loss: 1.2771 - accuracy: 0.6421 - val_loss: 1.2454 - val_accuracy: 0.6944 - 610ms/epoch - 38ms/step
# Epoch 5/100
# 16/16 - 1s - loss: 1.2416 - accuracy: 0.6465 - val_loss: 1.2059 - val_accuracy: 0.7007 - 530ms/epoch - 33ms/step
# Epoch 6/100
# 16/16 - 1s - loss: 1.2418 - accuracy: 0.6477 - val_loss: 1.1994 - val_accuracy: 0.7013 - 520ms/epoch - 32ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 1.2271 - accuracy: 0.6469 - val_loss: 1.2152 - val_accuracy: 0.6813 - 456ms/epoch - 29ms/step
# Epoch 8/100
# 16/16 - 1s - loss: 1.2199 - accuracy: 0.6490 - val_loss: 1.1827 - val_accuracy: 0.6890 - 538ms/epoch - 34ms/step
# Epoch 9/100
# 16/16 - 1s - loss: 1.2172 - accuracy: 0.6610 - val_loss: 1.1776 - val_accuracy: 0.7068 - 512ms/epoch - 32ms/step
# Epoch 10/100
# 16/16 - 1s - loss: 1.2150 - accuracy: 0.6516 - val_loss: 1.2097 - val_accuracy: 0.7011 - 520ms/epoch - 32ms/step
# Epoch 11/100
# 16/16 - 1s - loss: 1.2066 - accuracy: 0.6631 - val_loss: 1.1755 - val_accuracy: 0.6933 - 531ms/epoch - 33ms/step
# Epoch 12/100
# 16/16 - 1s - loss: 1.2070 - accuracy: 0.6554 - val_loss: 1.1480 - val_accuracy: 0.6855 - 521ms/epoch - 33ms/step
# Epoch 13/100
# 16/16 - 1s - loss: 1.2017 - accuracy: 0.6551 - val_loss: 1.1909 - val_accuracy: 0.6854 - 546ms/epoch - 34ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 1.2044 - accuracy: 0.6585 - val_loss: 1.1859 - val_accuracy: 0.7032 - 280ms/epoch - 18ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 1.2110 - accuracy: 0.6579 - val_loss: 1.1904 - val_accuracy: 0.6849 - 276ms/epoch - 17ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 1.1997 - accuracy: 0.6622 - val_loss: 1.1996 - val_accuracy: 0.6858 - 278ms/epoch - 17ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 1.1984 - accuracy: 0.6681 - val_loss: 1.1488 - val_accuracy: 0.7087 - 275ms/epoch - 17ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 1.1965 - accuracy: 0.6652 - val_loss: 1.1576 - val_accuracy: 0.6937 - 264ms/epoch - 17ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 1.1940 - accuracy: 0.6619 - val_loss: 1.1847 - val_accuracy: 0.7074 - 284ms/epoch - 18ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 1.1940 - accuracy: 0.6679 - val_loss: 1.1786 - val_accuracy: 0.6960 - 281ms/epoch - 18ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 1.1908 - accuracy: 0.6682 - val_loss: 1.1571 - val_accuracy: 0.6947 - 264ms/epoch - 17ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 1.1838 - accuracy: 0.6729 - val_loss: 1.1499 - val_accuracy: 0.7075 - 277ms/epoch - 17ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 1.1797 - accuracy: 0.6726 - val_loss: 1.1505 - val_accuracy: 0.6936 - 288ms/epoch - 18ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 1.1842 - accuracy: 0.6741 - val_loss: 1.1614 - val_accuracy: 0.7094 - 284ms/epoch - 18ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 1.1818 - accuracy: 0.6730 - val_loss: 1.1798 - val_accuracy: 0.7106 - 274ms/epoch - 17ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 1.1804 - accuracy: 0.6720 - val_loss: 1.1337 - val_accuracy: 0.7053 - 415ms/epoch - 26ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 1.1838 - accuracy: 0.6673 - val_loss: 1.1357 - val_accuracy: 0.7111 - 378ms/epoch - 24ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 1.1875 - accuracy: 0.6678 - val_loss: 1.1634 - val_accuracy: 0.7110 - 422ms/epoch - 26ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 1.1802 - accuracy: 0.6769 - val_loss: 1.1415 - val_accuracy: 0.7164 - 418ms/epoch - 26ms/step
# Epoch 30/100
# 16/16 - 1s - loss: 1.1802 - accuracy: 0.6771 - val_loss: 1.1556 - val_accuracy: 0.6964 - 509ms/epoch - 32ms/step
# Epoch 31/100
# 16/16 - 1s - loss: 1.1787 - accuracy: 0.6734 - val_loss: 1.1786 - val_accuracy: 0.7108 - 523ms/epoch - 33ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 1.1868 - accuracy: 0.6776 - val_loss: 1.1376 - val_accuracy: 0.7149 - 266ms/epoch - 17ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 1.1772 - accuracy: 0.6767 - val_loss: 1.1324 - val_accuracy: 0.6935 - 260ms/epoch - 16ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 1.1775 - accuracy: 0.6801 - val_loss: 1.1708 - val_accuracy: 0.7048 - 291ms/epoch - 18ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 1.1852 - accuracy: 0.6739 - val_loss: 1.1668 - val_accuracy: 0.7129 - 268ms/epoch - 17ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 1.1855 - accuracy: 0.6722 - val_loss: 1.1408 - val_accuracy: 0.7102 - 260ms/epoch - 16ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 1.1730 - accuracy: 0.6853 - val_loss: 1.1379 - val_accuracy: 0.7167 - 433ms/epoch - 27ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 1.1877 - accuracy: 0.6715 - val_loss: 1.1600 - val_accuracy: 0.7122 - 262ms/epoch - 16ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 1.1838 - accuracy: 0.6755 - val_loss: 1.1504 - val_accuracy: 0.7113 - 277ms/epoch - 17ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 1.1729 - accuracy: 0.6778 - val_loss: 1.1484 - val_accuracy: 0.7128 - 263ms/epoch - 16ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 1.1851 - accuracy: 0.6720 - val_loss: 1.1566 - val_accuracy: 0.7155 - 298ms/epoch - 19ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 1.1888 - accuracy: 0.6731 - val_loss: 1.1400 - val_accuracy: 0.6990 - 269ms/epoch - 17ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 1.1761 - accuracy: 0.6737 - val_loss: 1.1514 - val_accuracy: 0.7123 - 266ms/epoch - 17ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 1.1760 - accuracy: 0.6720 - val_loss: 1.1480 - val_accuracy: 0.7126 - 435ms/epoch - 27ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 1.1744 - accuracy: 0.6750 - val_loss: 1.1494 - val_accuracy: 0.7073 - 283ms/epoch - 18ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 1.1713 - accuracy: 0.6823 - val_loss: 1.1514 - val_accuracy: 0.7133 - 288ms/epoch - 18ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 1.1683 - accuracy: 0.6782 - val_loss: 1.1084 - val_accuracy: 0.7164 - 298ms/epoch - 19ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 1.1689 - accuracy: 0.6794 - val_loss: 1.1317 - val_accuracy: 0.7071 - 257ms/epoch - 16ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 1.1674 - accuracy: 0.6850 - val_loss: 1.1607 - val_accuracy: 0.7126 - 262ms/epoch - 16ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 1.1737 - accuracy: 0.6785 - val_loss: 1.1386 - val_accuracy: 0.7103 - 266ms/epoch - 17ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 1.1672 - accuracy: 0.6872 - val_loss: 1.1313 - val_accuracy: 0.7124 - 311ms/epoch - 19ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 1.1646 - accuracy: 0.6807 - val_loss: 1.1433 - val_accuracy: 0.7147 - 448ms/epoch - 28ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 1.1869 - accuracy: 0.6704 - val_loss: 1.1382 - val_accuracy: 0.7118 - 274ms/epoch - 17ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 1.1751 - accuracy: 0.6788 - val_loss: 1.1218 - val_accuracy: 0.7102 - 270ms/epoch - 17ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 1.1654 - accuracy: 0.6827 - val_loss: 1.1570 - val_accuracy: 0.7132 - 271ms/epoch - 17ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 1.1702 - accuracy: 0.6801 - val_loss: 1.1365 - val_accuracy: 0.7137 - 269ms/epoch - 17ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 1.1706 - accuracy: 0.6846 - val_loss: 1.1201 - val_accuracy: 0.7139 - 272ms/epoch - 17ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 1.1744 - accuracy: 0.6776 - val_loss: 1.1577 - val_accuracy: 0.6916 - 281ms/epoch - 18ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 1.1742 - accuracy: 0.6701 - val_loss: 1.1493 - val_accuracy: 0.7118 - 264ms/epoch - 17ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 1.1711 - accuracy: 0.6715 - val_loss: 1.1479 - val_accuracy: 0.6931 - 267ms/epoch - 17ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 1.1650 - accuracy: 0.6825 - val_loss: 1.1376 - val_accuracy: 0.7144 - 288ms/epoch - 18ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 1.1770 - accuracy: 0.6763 - val_loss: 1.1307 - val_accuracy: 0.7104 - 276ms/epoch - 17ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 1.1674 - accuracy: 0.6853 - val_loss: 1.1334 - val_accuracy: 0.6913 - 250ms/epoch - 16ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 1.1724 - accuracy: 0.6789 - val_loss: 1.1503 - val_accuracy: 0.7100 - 273ms/epoch - 17ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 1.1763 - accuracy: 0.6797 - val_loss: 1.1657 - val_accuracy: 0.6870 - 269ms/epoch - 17ms/step
# Epoch 66/100
# 16/16 - 1s - loss: 1.1846 - accuracy: 0.6731 - val_loss: 1.1435 - val_accuracy: 0.7037 - 511ms/epoch - 32ms/step
# Epoch 67/100
# 16/16 - 1s - loss: 1.1781 - accuracy: 0.6741 - val_loss: 1.1343 - val_accuracy: 0.7137 - 518ms/epoch - 32ms/step
# Epoch 68/100
# 16/16 - 1s - loss: 1.1705 - accuracy: 0.6734 - val_loss: 1.1300 - val_accuracy: 0.6989 - 517ms/epoch - 32ms/step
# Epoch 69/100
# 16/16 - 1s - loss: 1.1662 - accuracy: 0.6806 - val_loss: 1.1294 - val_accuracy: 0.7125 - 518ms/epoch - 32ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 1.1656 - accuracy: 0.6715 - val_loss: 1.1600 - val_accuracy: 0.7101 - 414ms/epoch - 26ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 1.1682 - accuracy: 0.6807 - val_loss: 1.1365 - val_accuracy: 0.6926 - 272ms/epoch - 17ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 1.1676 - accuracy: 0.6786 - val_loss: 1.1026 - val_accuracy: 0.7120 - 272ms/epoch - 17ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 1.1620 - accuracy: 0.6798 - val_loss: 1.1391 - val_accuracy: 0.7164 - 265ms/epoch - 17ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 1.1647 - accuracy: 0.6836 - val_loss: 1.1442 - val_accuracy: 0.7083 - 266ms/epoch - 17ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 1.1662 - accuracy: 0.6764 - val_loss: 1.1160 - val_accuracy: 0.7172 - 265ms/epoch - 17ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 1.1635 - accuracy: 0.6827 - val_loss: 1.1576 - val_accuracy: 0.6976 - 270ms/epoch - 17ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 1.1583 - accuracy: 0.6806 - val_loss: 1.1214 - val_accuracy: 0.7136 - 268ms/epoch - 17ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 1.1681 - accuracy: 0.6775 - val_loss: 1.1209 - val_accuracy: 0.7054 - 271ms/epoch - 17ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 1.1663 - accuracy: 0.6815 - val_loss: 1.1649 - val_accuracy: 0.6956 - 444ms/epoch - 28ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 1.1712 - accuracy: 0.6772 - val_loss: 1.1380 - val_accuracy: 0.7153 - 449ms/epoch - 28ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 1.1711 - accuracy: 0.6731 - val_loss: 1.1302 - val_accuracy: 0.7116 - 284ms/epoch - 18ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 1.1617 - accuracy: 0.6857 - val_loss: 1.1145 - val_accuracy: 0.7107 - 286ms/epoch - 18ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 1.1667 - accuracy: 0.6839 - val_loss: 1.1337 - val_accuracy: 0.7108 - 286ms/epoch - 18ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 1.1728 - accuracy: 0.6735 - val_loss: 1.1327 - val_accuracy: 0.7112 - 281ms/epoch - 18ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 1.1645 - accuracy: 0.6833 - val_loss: 1.1637 - val_accuracy: 0.6903 - 277ms/epoch - 17ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 1.1682 - accuracy: 0.6789 - val_loss: 1.1276 - val_accuracy: 0.7112 - 290ms/epoch - 18ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 1.1720 - accuracy: 0.6754 - val_loss: 1.1208 - val_accuracy: 0.7086 - 278ms/epoch - 17ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 1.1631 - accuracy: 0.6795 - val_loss: 1.1400 - val_accuracy: 0.7144 - 274ms/epoch - 17ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 1.1629 - accuracy: 0.6825 - val_loss: 1.1221 - val_accuracy: 0.7056 - 271ms/epoch - 17ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 1.1713 - accuracy: 0.6781 - val_loss: 1.1366 - val_accuracy: 0.7146 - 285ms/epoch - 18ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 1.1726 - accuracy: 0.6711 - val_loss: 1.1449 - val_accuracy: 0.7136 - 274ms/epoch - 17ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 1.1734 - accuracy: 0.6765 - val_loss: 1.1221 - val_accuracy: 0.7073 - 279ms/epoch - 17ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 1.1705 - accuracy: 0.6844 - val_loss: 1.1217 - val_accuracy: 0.7097 - 442ms/epoch - 28ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 1.1729 - accuracy: 0.6755 - val_loss: 1.1622 - val_accuracy: 0.7114 - 276ms/epoch - 17ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 1.1738 - accuracy: 0.6863 - val_loss: 1.1675 - val_accuracy: 0.6829 - 275ms/epoch - 17ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 1.1718 - accuracy: 0.6845 - val_loss: 1.1256 - val_accuracy: 0.6957 - 445ms/epoch - 28ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 1.1630 - accuracy: 0.6814 - val_loss: 1.1613 - val_accuracy: 0.6838 - 279ms/epoch - 17ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 1.1656 - accuracy: 0.6809 - val_loss: 1.1332 - val_accuracy: 0.7083 - 271ms/epoch - 17ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 1.1745 - accuracy: 0.6772 - val_loss: 1.1319 - val_accuracy: 0.7057 - 444ms/epoch - 28ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 1.1674 - accuracy: 0.6895 - val_loss: 1.1601 - val_accuracy: 0.7032 - 281ms/epoch - 18ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model3.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 300/300 [==============================] - 0s 2ms/step - loss: 1.1590 - accuracy: 0.7034
#
#
# accuracy= 0.7033827304840088

# %%
predictions3 = (model3.predict(x_test) > 0.5).astype("int32")
# Out:
# 300/300 [==============================] - 0s 1ms/step

# %%
print(classification_report(predictions3,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.84      0.63      2859
#            1       0.90      0.64      0.75      6719
#
#     accuracy                           0.70      9578
#    macro avg       0.70      0.74      0.69      9578
# weighted avg       0.78      0.70      0.72      9578

# %%
cm1 = confusion_matrix(predictions1,y_test)
cm2 = confusion_matrix(predictions,y_test)
cm3 = confusion_matrix(predictions2,y_test)
cm4 = confusion_matrix(predictions3,y_test)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

axs[0, 0].imshow(cm1, cmap='Blues', interpolation='nearest')
axs[0, 0].set_title('Without any Regularizers')
axs[0, 0].set_xlabel('Predicted')
axs[0, 0].set_ylabel('True')

axs[0, 1].imshow(cm2, cmap='Blues', interpolation='nearest')
axs[0, 1].set_title('With L1 Regularizer')
axs[0, 1].set_xlabel('Predicted')
axs[0, 1].set_ylabel('True')

axs[1, 0].imshow(cm3, cmap='Blues', interpolation='nearest')
axs[1, 0].set_title('With L2 Regularizer')
axs[1, 0].set_xlabel('Predicted')
axs[1, 0].set_ylabel('True')

axs[1, 1].imshow(cm4, cmap='Blues', interpolation='nearest')
axs[1, 1].set_title('With Elastic Net Regularizer')
axs[1, 1].set_xlabel('Predicted')
axs[1, 1].set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
precision1, recall1, _ = precision_recall_curve(y_test, predictions1)
precision2, recall2, _ = precision_recall_curve(y_test, predictions)
precision3, recall3, _ = precision_recall_curve(y_test, predictions2)
precision4, recall4, _ = precision_recall_curve(y_test, predictions3)

# Plot precision-recall curves
plt.plot(recall1, precision1, label='Without Regularization')
plt.plot(recall2, precision2, label='With L1 Regularizer')
plt.plot(recall3, precision3, label='With L2 Regularizer')
plt.plot(recall4, precision4, label='With Elastic Net Regularizer')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %%
fpr1, tpr1, _ = roc_curve(y_test, predictions1)
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, _ = roc_curve(y_test, predictions)
roc_auc2 = auc(fpr2, tpr2)

fpr3, tpr3, _ = roc_curve(y_test, predictions2)
roc_auc3 = auc(fpr3, tpr3)

fpr4, tpr4, _ = roc_curve(y_test, predictions3)
roc_auc4 = auc(fpr4, tpr4)

# Plot ROC curves
plt.plot(fpr1, tpr1, label='Without Regularization (AUC = %0.2f)' % roc_auc1)
plt.plot(fpr2, tpr2, label='Applying L1 Regularization (AUC = %0.2f)' % roc_auc2)
plt.plot(fpr3, tpr3, label='Applying L2 Regularization (AUC = %0.2f)' % roc_auc3)
plt.plot(fpr4, tpr4, label='Applying Elastic Net Regularization (AUC = %0.2f)' % roc_auc4)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **INFERENCE**
#
# ---
#
# Regularization techniques like L1, L2, and Elastic Net are used to prevent overfitting in machine learning models. L1 regularization (Lasso) adds a penalty term to the loss function that encourages sparsity in the model, meaning it tends to set some of the weights to zero, effectively removing some features from the model. L2 regularization (Ridge) adds a penalty term to the loss function that shrinks the weights towards zero without encouraging sparsity. Elastic Net regularization is a combination of L1 and L2 regularization, providing a balance between sparsity and shrinkage of the weights. In the medical domain, where datasets often have a moderate number of features and avoiding overfitting is crucial, L2 regularization is often a good choice.
